# %% [markdown]
# # Making a new virtual Python environment
#
# Everytime we start UCloud, it will start a fresh version of Python. This means that we have to install everything.
#
# This takes a lot of time. A way to prevent this is to install your own version of Python in something called an environment. An environment is really just a folder that contains all the Python scripts that you decide to install for a particular project.

# %%
import os
import shutil
import pip

# %% [markdown]
# ## Make your own folder in the 'student_folders' directory
# ## IMPORTANT: Don't mess around with other people's folders!!
# Everybody has editing rights on the student_folders, so take care.
#
# If you worry, you can also run everything from your own private folder.

# %%
# The student folder is called
student_folder='/work/807746'
my_folder='mikkels_folder' #make your own
os.chdir(student_folder)

my_path = os.path.join(student_folder, my_folder)
# Make directory
os.mkdir(my_path)
#If you get an error here, the folder name is already in use

#If you want to remove your folder and start over, comment out the mkdir line and uncomment this line:
#shutil.rmtree(my_path) # Use shutil to remove entire folder with content.

# %% [markdown]
# ## Move notebooks to a folder where you can work on them and write results, if needed

# %%
# Folder where notebooks are saved
notebook_source='/work/798873'
# Working folder for notebooks
notebook_destination = os.path.join(my_path, 'notebooks')
shutil.copytree(notebook_source, notebook_destination)
#If you get an error here, you may already have moved the files.
# Out:
# '/work/807746/mikkels_folder/notebooks'

# %% [markdown]
# ## Remove old virtual environment in notebook folder, if it exists

# %%
#Define local path and environment name. You need to change this to your local folder.

env_name='virt_env' # Name of the virtual environment

env_path=os.path.join(notebook_destination,env_name)
os.chdir(path)

shutil.rmtree(env_path) # Use shutil to remove entire folder with content.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 env_name='virt_env' # Name of the virtual environment
#       5 env_path=os.path.join(notebook_destination,env_name)
# ----> 6 os.chdir(path)
#       8 shutil.rmtree(env_path) # Use shutil to remove entire folder with content.
#
# NameError: name 'path' is not defined

# %% [markdown]
# ## Make a new virtual environment and activate it
#
# Code is in a small shell script called ```setup.sh``` This should be located in your working directory. If not, save the following in a file with this filename.
#
# ```bash
# python -m venv virt_env
# . /work/<MY DIRECTORY NUMBER>/virt_env/bin/activate
# python -m pip install ipykernel
# python -m ipykernel install --user --name=virt_env
# echo Done!
# ```
#
# To investigate/edit the content of the bash file, you can open it using a text editor. The script contains code that you could use in the terminal.
#
# The script creates and activates a virtual environment called ```virt_env```
#
# In this environment it installs an iPython kernel called ```virt_env```

# %%
path=my_path
os.chdir(path)
# Running setup.sh "!" is used to run terminal commands in jupyter.
# !./setup.sh
# Out:
# Collecting ipykernel
#   Downloading ipykernel-6.25.0-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 kB 2.4 MB/s eta 0:00:0000:01
# Collecting psutil
#   Downloading psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 kB 1.7 MB/s eta 0:00:0000:01
# Collecting comm>=0.1.1
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting packaging
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 1.6 MB/s eta 0:00:00
# Collecting tornado>=6.1
#   Downloading tornado-6.3.2-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.9/426.9 kB 11.0 MB/s eta 0:00:0000:01
# Collecting pyzmq>=20
#   Downloading pyzmq-25.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.0 MB/s eta 0:00:00:00:01
# Collecting matplotlib-inline>=0.1
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting debugpy>=1.6.5
#   Downloading debugpy-1.6.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 14.5 MB/s eta 0:00:00:00:01
# Collecting jupyter-core!=5.0.*,>=4.12
#   Downloading jupyter_core-5.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 1.8 MB/s eta 0:00:00:00:01
# Collecting ipython>=7.23.1
#   Downloading ipython-8.14.0-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.7/798.7 kB 13.9 MB/s eta 0:00:0000:01
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 8.4 MB/s eta 0:00:00
# Collecting traitlets>=5.4.0
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.4/117.4 kB 5.3 MB/s eta 0:00:00
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.7-py3-none-any.whl (5.3 kB)
# Collecting jedi>=0.16
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 30.9 MB/s eta 0:00:00:00:01
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 5.6 MB/s eta 0:00:00
# Collecting pygments>=2.4.0
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.2 MB/s eta 0:00:00
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30
#   Downloading prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 9.7 MB/s eta 0:00:0000:01
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting stack-data
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Collecting python-dateutil>=2.8.2
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 8.4 MB/s eta 0:00:00
# Collecting platformdirs>=2.5
#   Downloading platformdirs-3.10.0-py3-none-any.whl (17 kB)
# Collecting parso<0.9.0,>=0.8.3
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.6 MB/s eta 0:00:00
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting executing>=1.2.0
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, pickleshare, executing, backcall, traitlets, tornado, six, pyzmq, pygments, psutil, prompt-toolkit, platformdirs, pexpect, parso, packaging, nest-asyncio, decorator, debugpy, python-dateutil, matplotlib-inline, jupyter-core, jedi, comm, asttokens, stack-data, jupyter-client, ipython, ipykernel
# Successfully installed asttokens-2.2.1 backcall-0.2.0 comm-0.1.4 debugpy-1.6.8 decorator-5.1.1 executing-1.2.0 ipykernel-6.25.0 ipython-8.14.0 jedi-0.19.0 jupyter-client-8.3.0 jupyter-core-5.3.1 matplotlib-inline-0.1.6 nest-asyncio-1.5.7 packaging-23.1 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 platformdirs-3.10.0 prompt-toolkit-3.0.39 psutil-5.9.5 ptyprocess-0.7.0 pure-eval-0.2.2 pygments-2.15.1 python-dateutil-2.8.2 pyzmq-25.1.0 six-1.16.0 stack-data-0.6.2 tornado-6.3.2 traitlets-5.9.0 wcwidth-0.2.6
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Installed kernelspec virt_env in /home/ucloud/.local/share/jupyter/kernels/virt_env
# Done!

# %% [markdown]
# ## Change the iPython kernel
# You can now change the kernel you are using for this notebook by
# - pressing "kernel" in the menu above
# - clicking "change kernel"
# - Selecting the kernel with the name (e.g. ```virt_env```) specified above.
#
# You should now see the name of your ipython kernel in the top right of the window.
#
# We can also check which environment we are in by running the code below:

# %%
import sys
import os
print(sys.executable)
# Out:
# /work/798873/virt_env/bin/python

# %% [markdown]
# It should have the ```virt_env``` name in the path.
#
# If it says ```/opt/conda/bin/python``` then you are still in the original environment.
#
# The cool thing is that this environment is kept, even when the run is closed or runs out of time, so you only have to install this once.
#
# ### Checking that the environment is empty
# Given that you have just made the virtual environment, it should not have any Python packages installed.
#
# Let's see if this is true:

# %%
import nilearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import nilearn
#
# ModuleNotFoundError: No module named 'nilearn'

# %% [markdown]
# If you got an error here, you are in  a fresh environment.

# %% [markdown]
# ### Install modules for neuroimaging
# Now, let's install some packages that we will use in the course.
#
# We will use a bash script for this as well. The script called ```install_python_packages.sh``` This should be located in your working directory. If not, save the following in a file with this filename.
#
# ```bash
# . /work/<MY DIRECTORY NUMBER>/virt_env/bin/activate
# python -m pip install imageio
# python -m pip install scipy
# python -m pip install numpy
# python -m pip install matplotlib
# python -m pip install dicom2nifti
# python -m pip install nibabel
# python -m pip install nilearn
# python -m pip install scikit-learn
# python -m pip install mne
# python -m pip install seaborn
# python -m pip install crtoolbox
# python -m pip install ipywidgets
# python -m pip install pandas
# python -m pip install pyvistaqt
# python -m pip install itertools
# python -m pip install ndslib
# python -m pip install pickle
# echo Done!
# ```

# %%
# ! is used to run terminal commands.
import os
path='/work/798873' # Place where you keep your files
os.chdir(path)
# !./install_python_packages.sh
# Out:
# Requirement already satisfied: imageio in ./virt_env/lib/python3.10/site-packages (2.31.1)
# Requirement already satisfied: numpy in ./virt_env/lib/python3.10/site-packages (from imageio) (1.25.2)
# Requirement already satisfied: pillow>=8.3.2 in ./virt_env/lib/python3.10/site-packages (from imageio) (10.0.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scipy in ./virt_env/lib/python3.10/site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in ./virt_env/lib/python3.10/site-packages (from scipy) (1.25.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in ./virt_env/lib/python3.10/site-packages (1.25.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib==3.7.1 in ./virt_env/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: packaging>=20.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (23.1)
# Requirement already satisfied: numpy>=1.20 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (1.25.2)
# Requirement already satisfied: pillow>=6.2.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (10.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (4.42.0)
# Requirement already satisfied: cycler>=0.10 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib==3.7.1) (1.1.0)
# Requirement already satisfied: six>=1.5 in ./virt_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.1) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: dicom2nifti in ./virt_env/lib/python3.10/site-packages (2.4.8)
# Requirement already satisfied: pydicom>=2.2.0 in ./virt_env/lib/python3.10/site-packages (from dicom2nifti) (2.4.2)
# Requirement already satisfied: scipy in ./virt_env/lib/python3.10/site-packages (from dicom2nifti) (1.11.1)
# Requirement already satisfied: nibabel in ./virt_env/lib/python3.10/site-packages (from dicom2nifti) (5.1.0)
# Requirement already satisfied: python-gdcm in ./virt_env/lib/python3.10/site-packages (from dicom2nifti) (3.0.22)
# Requirement already satisfied: numpy in ./virt_env/lib/python3.10/site-packages (from dicom2nifti) (1.25.2)
# Requirement already satisfied: packaging>=17 in ./virt_env/lib/python3.10/site-packages (from nibabel->dicom2nifti) (23.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: nibabel in ./virt_env/lib/python3.10/site-packages (5.1.0)
# Requirement already satisfied: packaging>=17 in ./virt_env/lib/python3.10/site-packages (from nibabel) (23.1)
# Requirement already satisfied: numpy>=1.19 in ./virt_env/lib/python3.10/site-packages (from nibabel) (1.25.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: nilearn in ./virt_env/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: lxml in ./virt_env/lib/python3.10/site-packages (from nilearn) (4.9.3)
# Requirement already satisfied: pandas>=1.1.5 in ./virt_env/lib/python3.10/site-packages (from nilearn) (2.0.3)
# Requirement already satisfied: numpy>=1.19.0 in ./virt_env/lib/python3.10/site-packages (from nilearn) (1.25.2)
# Requirement already satisfied: nibabel>=3.2.0 in ./virt_env/lib/python3.10/site-packages (from nilearn) (5.1.0)
# Requirement already satisfied: scipy>=1.6.0 in ./virt_env/lib/python3.10/site-packages (from nilearn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./virt_env/lib/python3.10/site-packages (from nilearn) (1.3.0)
# Requirement already satisfied: packaging in ./virt_env/lib/python3.10/site-packages (from nilearn) (23.1)
# Requirement already satisfied: joblib>=1.0.0 in ./virt_env/lib/python3.10/site-packages (from nilearn) (1.3.1)
# Requirement already satisfied: requests>=2.25.0 in ./virt_env/lib/python3.10/site-packages (from nilearn) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./virt_env/lib/python3.10/site-packages (from pandas>=1.1.5->nilearn) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in ./virt_env/lib/python3.10/site-packages (from pandas>=1.1.5->nilearn) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in ./virt_env/lib/python3.10/site-packages (from pandas>=1.1.5->nilearn) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./virt_env/lib/python3.10/site-packages (from scikit-learn>=1.0.0->nilearn) (3.2.0)
# Requirement already satisfied: six>=1.5 in ./virt_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->nilearn) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in ./virt_env/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in ./virt_env/lib/python3.10/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./virt_env/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in ./virt_env/lib/python3.10/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: numpy>=1.17.3 in ./virt_env/lib/python3.10/site-packages (from scikit-learn) (1.25.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: mne in ./virt_env/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.15.4 in ./virt_env/lib/python3.10/site-packages (from mne) (1.25.2)
# Requirement already satisfied: matplotlib>=3.4.0 in ./virt_env/lib/python3.10/site-packages (from mne) (3.7.1)
# Requirement already satisfied: pooch>=1.5 in ./virt_env/lib/python3.10/site-packages (from mne) (1.7.0)
# Requirement already satisfied: scipy>=1.6.3 in ./virt_env/lib/python3.10/site-packages (from mne) (1.11.1)
# Requirement already satisfied: tqdm in ./virt_env/lib/python3.10/site-packages (from mne) (4.65.0)
# Requirement already satisfied: jinja2 in ./virt_env/lib/python3.10/site-packages (from mne) (3.1.2)
# Requirement already satisfied: packaging in ./virt_env/lib/python3.10/site-packages (from mne) (23.1)
# Requirement already satisfied: decorator in ./virt_env/lib/python3.10/site-packages (from mne) (5.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib>=3.4.0->mne) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib>=3.4.0->mne) (4.42.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./virt_env/lib/python3.10/site-packages (from matplotlib>=3.4.0->mne) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib>=3.4.0->mne) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in ./virt_env/lib/python3.10/site-packages (from matplotlib>=3.4.0->mne) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib>=3.4.0->mne) (1.1.0)
# Requirement already satisfied: pillow>=6.2.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib>=3.4.0->mne) (10.0.0)
# Requirement already satisfied: requests>=2.19.0 in ./virt_env/lib/python3.10/site-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./virt_env/lib/python3.10/site-packages (from pooch>=1.5->mne) (3.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./virt_env/lib/python3.10/site-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: six>=1.5 in ./virt_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.4.0->mne) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./virt_env/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./virt_env/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./virt_env/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./virt_env/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.2.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: seaborn in ./virt_env/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in ./virt_env/lib/python3.10/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in ./virt_env/lib/python3.10/site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in ./virt_env/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: packaging>=20.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: cycler>=0.10 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in ./virt_env/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./virt_env/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in ./virt_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: crtoolbox in ./virt_env/lib/python3.10/site-packages (0.1.6)
# Requirement already satisfied: matplotlib in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (3.7.1)
# Requirement already satisfied: numpy in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (1.25.2)
# Requirement already satisfied: nibabel in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (5.1.0)
# Requirement already satisfied: pyyaml in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (6.0.1)
# Requirement already satisfied: plotly in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (5.15.0)
# Requirement already satisfied: nbformat>=4.2.0 in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (5.9.2)
# Requirement already satisfied: nilearn in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (0.10.1)
# Requirement already satisfied: pandas in ./virt_env/lib/python3.10/site-packages (from crtoolbox) (2.0.3)
# Requirement already satisfied: jupyter-core in ./virt_env/lib/python3.10/site-packages (from nbformat>=4.2.0->crtoolbox) (5.3.1)
# Requirement already satisfied: traitlets>=5.1 in ./virt_env/lib/python3.10/site-packages (from nbformat>=4.2.0->crtoolbox) (5.9.0)
# Requirement already satisfied: fastjsonschema in ./virt_env/lib/python3.10/site-packages (from nbformat>=4.2.0->crtoolbox) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in ./virt_env/lib/python3.10/site-packages (from nbformat>=4.2.0->crtoolbox) (4.18.6)
# Requirement already satisfied: contourpy>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (23.1)
# Requirement already satisfied: cycler>=0.10 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (4.42.0)
# Requirement already satisfied: pillow>=6.2.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib->crtoolbox) (10.0.0)
# Requirement already satisfied: lxml in ./virt_env/lib/python3.10/site-packages (from nilearn->crtoolbox) (4.9.3)
# Requirement already satisfied: joblib>=1.0.0 in ./virt_env/lib/python3.10/site-packages (from nilearn->crtoolbox) (1.3.1)
# Requirement already satisfied: requests>=2.25.0 in ./virt_env/lib/python3.10/site-packages (from nilearn->crtoolbox) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./virt_env/lib/python3.10/site-packages (from nilearn->crtoolbox) (1.3.0)
# Requirement already satisfied: scipy>=1.6.0 in ./virt_env/lib/python3.10/site-packages (from nilearn->crtoolbox) (1.11.1)
# Requirement already satisfied: tzdata>=2022.1 in ./virt_env/lib/python3.10/site-packages (from pandas->crtoolbox) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in ./virt_env/lib/python3.10/site-packages (from pandas->crtoolbox) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in ./virt_env/lib/python3.10/site-packages (from plotly->crtoolbox) (8.2.2)
# Requirement already satisfied: referencing>=0.28.4 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->crtoolbox) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->crtoolbox) (0.9.2)
# Requirement already satisfied: attrs>=22.2.0 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->crtoolbox) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->crtoolbox) (2023.7.1)
# Requirement already satisfied: six>=1.5 in ./virt_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->crtoolbox) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->crtoolbox) (3.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./virt_env/lib/python3.10/site-packages (from scikit-learn>=1.0.0->nilearn->crtoolbox) (3.2.0)
# Requirement already satisfied: platformdirs>=2.5 in ./virt_env/lib/python3.10/site-packages (from jupyter-core->nbformat>=4.2.0->crtoolbox) (3.10.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipywidgets in ./virt_env/lib/python3.10/site-packages (8.1.0)
# Requirement already satisfied: ipython>=6.1.0 in ./virt_env/lib/python3.10/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: comm>=0.1.3 in ./virt_env/lib/python3.10/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: traitlets>=4.3.1 in ./virt_env/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in ./virt_env/lib/python3.10/site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in ./virt_env/lib/python3.10/site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: pexpect>4.3 in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.0)
# Requirement already satisfied: pygments>=2.4.0 in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: decorator in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: stack-data in ./virt_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./virt_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./virt_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in ./virt_env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: pure-eval in ./virt_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./virt_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./virt_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: six in ./virt_env/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pandas in ./virt_env/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./virt_env/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./virt_env/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./virt_env/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./virt_env/lib/python3.10/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in ./virt_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement itertools (from versions: none)
# ERROR: No matching distribution found for itertools
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ndslib in ./virt_env/lib/python3.10/site-packages (0.6)
# Requirement already satisfied: jupyter in ./virt_env/lib/python3.10/site-packages (from ndslib) (1.0.0)
# Requirement already satisfied: seaborn in ./virt_env/lib/python3.10/site-packages (from ndslib) (0.12.2)
# Requirement already satisfied: numpydoc in ./virt_env/lib/python3.10/site-packages (from ndslib) (1.5.0)
# Requirement already satisfied: scikit-image in ./virt_env/lib/python3.10/site-packages (from ndslib) (0.21.0)
# Requirement already satisfied: matplotlib in ./virt_env/lib/python3.10/site-packages (from ndslib) (3.7.1)
# Requirement already satisfied: sphinx in ./virt_env/lib/python3.10/site-packages (from ndslib) (6.2.1)
# Requirement already satisfied: sphinx-rtd-theme in ./virt_env/lib/python3.10/site-packages (from ndslib) (1.2.2)
# Requirement already satisfied: numpy in ./virt_env/lib/python3.10/site-packages (from ndslib) (1.25.2)
# Requirement already satisfied: scikit-learn in ./virt_env/lib/python3.10/site-packages (from ndslib) (1.3.0)
# Requirement already satisfied: viznet in ./virt_env/lib/python3.10/site-packages (from ndslib) (0.3.0)
# Requirement already satisfied: sphinx-math-dollar in ./virt_env/lib/python3.10/site-packages (from ndslib) (1.2.1)
# Requirement already satisfied: nilearn in ./virt_env/lib/python3.10/site-packages (from ndslib) (0.10.1)
# Requirement already satisfied: pandas in ./virt_env/lib/python3.10/site-packages (from ndslib) (2.0.3)
# Requirement already satisfied: ipython in ./virt_env/lib/python3.10/site-packages (from ndslib) (8.14.0)
# Requirement already satisfied: sphinx-copybutton in ./virt_env/lib/python3.10/site-packages (from ndslib) (0.5.2)
# Requirement already satisfied: nibabel in ./virt_env/lib/python3.10/site-packages (from ndslib) (5.1.0)
# Requirement already satisfied: pygments>=2.4.0 in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (2.15.1)
# Requirement already satisfied: pexpect>4.3 in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (0.19.0)
# Requirement already satisfied: stack-data in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (0.6.2)
# Requirement already satisfied: traitlets>=5 in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (5.9.0)
# Requirement already satisfied: decorator in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (5.1.1)
# Requirement already satisfied: backcall in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (0.2.0)
# Requirement already satisfied: pickleshare in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (3.0.39)
# Requirement already satisfied: matplotlib-inline in ./virt_env/lib/python3.10/site-packages (from ipython->ndslib) (0.1.6)
# Requirement already satisfied: notebook in ./virt_env/lib/python3.10/site-packages (from jupyter->ndslib) (7.0.2)
# Requirement already satisfied: nbconvert in ./virt_env/lib/python3.10/site-packages (from jupyter->ndslib) (7.7.3)
# Requirement already satisfied: jupyter-console in ./virt_env/lib/python3.10/site-packages (from jupyter->ndslib) (6.6.3)
# Requirement already satisfied: ipykernel in ./virt_env/lib/python3.10/site-packages (from jupyter->ndslib) (6.25.0)
# Requirement already satisfied: qtconsole in ./virt_env/lib/python3.10/site-packages (from jupyter->ndslib) (5.4.3)
# Requirement already satisfied: ipywidgets in ./virt_env/lib/python3.10/site-packages (from jupyter->ndslib) (8.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (4.42.0)
# Requirement already satisfied: cycler>=0.10 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./virt_env/lib/python3.10/site-packages (from matplotlib->ndslib) (10.0.0)
# Requirement already satisfied: scipy>=1.6.0 in ./virt_env/lib/python3.10/site-packages (from nilearn->ndslib) (1.11.1)
# Requirement already satisfied: joblib>=1.0.0 in ./virt_env/lib/python3.10/site-packages (from nilearn->ndslib) (1.3.1)
# Requirement already satisfied: requests>=2.25.0 in ./virt_env/lib/python3.10/site-packages (from nilearn->ndslib) (2.31.0)
# Requirement already satisfied: lxml in ./virt_env/lib/python3.10/site-packages (from nilearn->ndslib) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in ./virt_env/lib/python3.10/site-packages (from pandas->ndslib) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./virt_env/lib/python3.10/site-packages (from pandas->ndslib) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./virt_env/lib/python3.10/site-packages (from scikit-learn->ndslib) (3.2.0)
# Requirement already satisfied: Jinja2>=2.10 in ./virt_env/lib/python3.10/site-packages (from numpydoc->ndslib) (3.1.2)
# Requirement already satisfied: sphinxcontrib-devhelp in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (1.0.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (0.7.13)
# Requirement already satisfied: snowballstemmer>=2.0 in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (2.2.0)
# Requirement already satisfied: imagesize>=1.3 in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (1.4.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (2.0.1)
# Requirement already satisfied: sphinxcontrib-jsmath in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (1.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (1.1.5)
# Requirement already satisfied: babel>=2.9 in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (2.12.1)
# Requirement already satisfied: sphinxcontrib-applehelp in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (1.0.4)
# Requirement already satisfied: docutils<0.20,>=0.18.1 in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (0.18.1)
# Requirement already satisfied: sphinxcontrib-qthelp in ./virt_env/lib/python3.10/site-packages (from sphinx->ndslib) (1.0.3)
# Requirement already satisfied: networkx>=2.8 in ./virt_env/lib/python3.10/site-packages (from scikit-image->ndslib) (3.1)
# Requirement already satisfied: tifffile>=2022.8.12 in ./virt_env/lib/python3.10/site-packages (from scikit-image->ndslib) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in ./virt_env/lib/python3.10/site-packages (from scikit-image->ndslib) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.2 in ./virt_env/lib/python3.10/site-packages (from scikit-image->ndslib) (0.3)
# Requirement already satisfied: imageio>=2.27 in ./virt_env/lib/python3.10/site-packages (from scikit-image->ndslib) (2.31.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in ./virt_env/lib/python3.10/site-packages (from sphinx-rtd-theme->ndslib) (4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./virt_env/lib/python3.10/site-packages (from jedi>=0.16->ipython->ndslib) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./virt_env/lib/python3.10/site-packages (from Jinja2>=2.10->numpydoc->ndslib) (2.1.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./virt_env/lib/python3.10/site-packages (from pexpect>4.3->ipython->ndslib) (0.7.0)
# Requirement already satisfied: wcwidth in ./virt_env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->ndslib) (0.2.6)
# Requirement already satisfied: six>=1.5 in ./virt_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->ndslib) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->ndslib) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->ndslib) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->ndslib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./virt_env/lib/python3.10/site-packages (from requests>=2.25.0->nilearn->ndslib) (3.4)
# Requirement already satisfied: tornado>=6.1 in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (6.3.2)
# Requirement already satisfied: pyzmq>=20 in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (25.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (1.6.8)
# Requirement already satisfied: psutil in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (5.9.5)
# Requirement already satisfied: comm>=0.1.1 in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (0.1.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (5.3.1)
# Requirement already satisfied: nest-asyncio in ./virt_env/lib/python3.10/site-packages (from ipykernel->jupyter->ndslib) (1.5.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in ./virt_env/lib/python3.10/site-packages (from ipywidgets->jupyter->ndslib) (3.0.8)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in ./virt_env/lib/python3.10/site-packages (from ipywidgets->jupyter->ndslib) (4.0.8)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (3.0.1)
# Requirement already satisfied: defusedxml in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (0.8.0)
# Requirement already satisfied: bleach!=5.0.0 in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (6.0.0)
# Requirement already satisfied: tinycss2 in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (1.2.1)
# Requirement already satisfied: nbformat>=5.7 in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in ./virt_env/lib/python3.10/site-packages (from nbconvert->jupyter->ndslib) (4.12.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in ./virt_env/lib/python3.10/site-packages (from notebook->jupyter->ndslib) (2.24.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./virt_env/lib/python3.10/site-packages (from notebook->jupyter->ndslib) (0.2.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./virt_env/lib/python3.10/site-packages (from notebook->jupyter->ndslib) (2.7.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in ./virt_env/lib/python3.10/site-packages (from notebook->jupyter->ndslib) (4.0.4)
# Requirement already satisfied: ipython-genutils in ./virt_env/lib/python3.10/site-packages (from qtconsole->jupyter->ndslib) (0.2.0)
# Requirement already satisfied: qtpy>=2.0.1 in ./virt_env/lib/python3.10/site-packages (from qtconsole->jupyter->ndslib) (2.3.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./virt_env/lib/python3.10/site-packages (from stack-data->ipython->ndslib) (2.2.1)
# Requirement already satisfied: pure-eval in ./virt_env/lib/python3.10/site-packages (from stack-data->ipython->ndslib) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in ./virt_env/lib/python3.10/site-packages (from stack-data->ipython->ndslib) (1.2.0)
# Requirement already satisfied: webencodings in ./virt_env/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter->ndslib) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in ./virt_env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->ndslib) (3.10.0)
# Requirement already satisfied: prometheus-client in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (0.17.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (0.7.0)
# Requirement already satisfied: websocket-client in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (1.6.1)
# Requirement already satisfied: argon2-cffi in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (21.3.0)
# Requirement already satisfied: send2trash in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (0.17.1)
# Requirement already satisfied: anyio>=3.1.0 in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (3.7.1)
# Requirement already satisfied: overrides in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (7.3.1)
# Requirement already satisfied: jupyter-server-terminals in ./virt_env/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (0.4.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./virt_env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->ndslib) (2.2.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./virt_env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->ndslib) (2.0.4)
# Requirement already satisfied: tomli in ./virt_env/lib/python3.10/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter->ndslib) (2.0.1)
# Requirement already satisfied: json5>=0.9.0 in ./virt_env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (0.9.14)
# Requirement already satisfied: jsonschema>=4.17.3 in ./virt_env/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (4.18.6)
# Requirement already satisfied: fastjsonschema in ./virt_env/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter->ndslib) (2.18.0)
# Requirement already satisfied: soupsieve>1.2 in ./virt_env/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->ndslib) (2.4.1)
# Requirement already satisfied: exceptiongroup in ./virt_env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (1.1.2)
# Requirement already satisfied: sniffio>=1.1 in ./virt_env/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./virt_env/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab<5,>=4.0.2->notebook->jupyter->ndslib) (4.7.1)
# Requirement already satisfied: referencing>=0.28.4 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (0.9.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (2023.7.1)
# Requirement already satisfied: attrs>=22.2.0 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (23.1.0)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./virt_env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (0.1.1)
# Requirement already satisfied: pyyaml>=5.3 in ./virt_env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (6.0.1)
# Requirement already satisfied: rfc3339-validator in ./virt_env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./virt_env/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in ./virt_env/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (21.2.0)
# Requirement already satisfied: isoduration in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (20.11.0)
# Requirement already satisfied: uri-template in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (2.4)
# Requirement already satisfied: fqdn in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (1.5.1)
# Requirement already satisfied: webcolors>=1.11 in ./virt_env/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in ./virt_env/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (1.15.1)
# Requirement already satisfied: pycparser in ./virt_env/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->ndslib) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in ./virt_env/lib/python3.10/site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter->ndslib) (1.2.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Done!

# %% [markdown]
# ### Checking which environment we are in and if it is still empty

# %%
import sys
print(sys.executable)
import nilearn
# Out:
# /work/798873/virt_env/bin/python

# %% [markdown]
# ### Setup done!
#
# We now have an installed virtual environment, and we can call on it when we need it by activating the environment and changing the ipython kernel in later notebooks.
#
# If for some reason you want to start over, you can always run this script again, and it will erase you old environment and make a new one. Before doing so, it might be wise to rename the old environment and keep it until you figure out if it was really a good idea to start from scratch.
#
# ### Don't save your files in the environment folder as they will be deleted too if you decide to start over.
